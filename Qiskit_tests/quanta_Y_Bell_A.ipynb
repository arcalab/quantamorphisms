# %% [markdown]
# # matrix fold of gate Y

# %%
# Checking the version of PYTHON; we only support > 3.5
import sys
sys.path.append('../../../Transferências/qiskit-sdk-py-master')

if sys.version_info < (3,5):
    raise Exception('Please use Python version 3.5 or greater.')

import qiskit
import numpy

# Import the QISKit
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QuantumProgram, Result
from qiskit import available_backends, execute, register, get_backend
import getpass, time
import Qconfig
from qiskit import compile


# import basic plot tools
from qiskit.tools.visualization import plot_histogram, circuit_drawer, plot_state

#information of API
from IBMQuantumExperience import IBMQuantumExperience

# Import tomography tools
import qiskit.tools.qcvv.tomography as tomo

# Aditional packages
from qiskit.tools.qi.qi import *

# %%
api = IBMQuantumExperience(Qconfig.APItoken)
myCredits = api.get_my_credits()

print(myCredits)

# set the APIToken and API url
try:
    register(Qconfig.APItoken,Qconfig.config['url'])

    print('\nYou have access to great power!')
    print(available_backends({'local': False, 'simulator': False}))
    print('Available simulators:')
    print(available_backends({'simulator':True}))
except: 
    print('Something went wrong.\nDid you enter a correct token?')
# Out:
# {'maxUserType': 15, 'promotional': 0, 'remaining': 15}
#
# You have access to great power!
# ['ibmq_16_rueschlikon', 'ibmq_5_tenerife', 'ibmq_5_yorktown']
# Available simulators:
# ['ibmq_qasm_simulator', 'local_qasm_simulator', 'local_statevector_simulator', 'local_unitary_simulator']

# %%
# Creating Programs
# create QuantumProgram object instance.
qp = QuantumProgram()

# Creating Registers
# create Quantum Register called "qr" with 3 qubits 
qr = qp.create_quantum_register('qr', 4)
# create Classical Register  called "cr" with 3 bits
cr = qp.create_classical_register('cr', 4)

# Creating Circuits
# create Quantum Circuit called "qc" involving your Quantum Register "qr"
# and your Classical Register "cr"
qc = qp.create_circuit('Circuit', [qr], [cr])

# %%
# Get the components.

# get the circuit by Name
circuit = qp.get_circuit('Circuit')

# get the Quantum Register by Name
quantum_r = qp.get_quantum_register('qr')

# get the Classical Register by Name
classical_r = qp.get_classical_register('cr')

# %%
#preparing qubits
qc.h(qr[3])
qc.cx(qr[3],qr[2])

# the circuit we want:
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[2])
qc.t(qr[3])
qc.tdg(qr[2])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[2])
qc.tdg(qr[0])
qc.t(qr[2])
qc.cx(qr[0],qr[2])
qc.h(qr[0])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[1],qr[0])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[2])
qc.tdg(qr[2])
qc.t(qr[0])
qc.cx(qr[3],qr[2])
qc.cx(qr[0],qr[3])
qc.t(qr[2])
qc.tdg(qr[3])
qc.cx(qr[3],qr[2])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[1])
qc.t(qr[3])
qc.t(qr[1])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[1])
qc.tdg(qr[0])
qc.tdg(qr[1])
qc.cx(qr[0],qr[1])
qc.h(qr[0])
qc.cx(qr[2],qr[0])
qc.tdg(qr[0])
qc.cx(qr[2],qr[0])
qc.t(qr[0])
qc.t(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[3],qr[1])
qc.cx(qr[0],qr[3])
qc.tdg(qr[1])
qc.tdg(qr[3])
qc.cx(qr[3],qr[1])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[1])
qc.t(qr[1])
qc.t(qr[3])
qc.t(qr[2])
qc.cx(qr[3],qr[2])
qc.cx(qr[1],qr[3])
qc.cx(qr[2],qr[1])
qc.tdg(qr[3])
qc.t(qr[1])
qc.cx(qr[2],qr[3])
qc.tdg(qr[3])
qc.tdg(qr[2])
qc.cx(qr[1],qr[3])
qc.cx(qr[2],qr[1])
qc.cx(qr[3],qr[2])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[2])
qc.tdg(qr[3])
qc.t(qr[2])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[2])
qc.tdg(qr[0])
qc.t(qr[2])
qc.cx(qr[0],qr[2])
qc.h(qr[0])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[1],qr[0])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[2])
qc.tdg(qr[2])
qc.t(qr[0])
qc.cx(qr[3],qr[2])
qc.cx(qr[0],qr[3])
qc.tdg(qr[2])
qc.t(qr[3])
qc.cx(qr[3],qr[2])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[1])
qc.tdg(qr[3])
qc.tdg(qr[1])
qc.cx(qr[0],qr[3])
qc.cx(qr[3],qr[1])
qc.tdg(qr[0])
qc.tdg(qr[1])
qc.cx(qr[0],qr[1])
qc.h(qr[0])
qc.cx(qr[2],qr[0])
qc.tdg(qr[0])
qc.cx(qr[2],qr[0])
qc.t(qr[0])
qc.t(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[3],qr[1])
qc.cx(qr[0],qr[3])
qc.t(qr[1])
qc.t(qr[3])
qc.cx(qr[3],qr[1])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[1])
qc.t(qr[1])
qc.tdg(qr[3])
qc.t(qr[2])
qc.cx(qr[3],qr[2])
qc.cx(qr[1],qr[3])
qc.cx(qr[2],qr[1])
qc.t(qr[3])
qc.tdg(qr[1])
qc.cx(qr[2],qr[3])
qc.tdg(qr[3])
qc.t(qr[2])
qc.cx(qr[1],qr[3])
qc.cx(qr[2],qr[1])
qc.cx(qr[3],qr[2])
qc.h(qr[1])


qc.measure(qr[1],cr[1])
qc.measure(qr[2],cr[2])
qc.measure(qr[3],cr[3])
# don't forget update the number of qubits and bits registered

# %%
circuit_drawer(qc)
# Out:
# <PIL.Image.Image image mode=RGB size=6557x400 at 0x7F618EE06E80>

# %%
qp.get_circuit_names()
# Out:
# ['Circuit']

# %%
# QASM from a program

QASM_source = qp.get_qasm('Circuit')

print(QASM_source)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[4];
# creg cr[4];
# h qr[3];
# cx qr[3],qr[2];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# t qr[3];
# tdg qr[2];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# tdg qr[0];
# t qr[2];
# cx qr[0],qr[2];
# h qr[0];
# tdg qr[1];
# tdg qr[0];
# cx qr[1],qr[0];
# t qr[0];
# cx qr[1],qr[0];
# h qr[0];
# cx qr[0],qr[2];
# tdg qr[2];
# t qr[0];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# t qr[2];
# tdg qr[3];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# h qr[0];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# t qr[3];
# t qr[1];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# tdg qr[0];
# tdg qr[1];
# cx qr[0],qr[1];
# h qr[0];
# cx qr[2],qr[0];
# tdg qr[0];
# cx qr[2],qr[0];
# t qr[0];
# t qr[2];
# h qr[0];
# cx qr[0],qr[1];
# t qr[1];
# t qr[0];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# tdg qr[1];
# tdg qr[3];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# h qr[0];
# h qr[1];
# t qr[1];
# t qr[3];
# t qr[2];
# cx qr[3],qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# tdg qr[3];
# t qr[1];
# cx qr[2],qr[3];
# tdg qr[3];
# tdg qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# cx qr[3],qr[2];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# tdg qr[3];
# t qr[2];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# tdg qr[0];
# t qr[2];
# cx qr[0],qr[2];
# h qr[0];
# tdg qr[1];
# tdg qr[0];
# cx qr[1],qr[0];
# t qr[0];
# cx qr[1],qr[0];
# h qr[0];
# cx qr[0],qr[2];
# tdg qr[2];
# t qr[0];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# tdg qr[2];
# t qr[3];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# h qr[0];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# tdg qr[3];
# tdg qr[1];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# tdg qr[0];
# tdg qr[1];
# cx qr[0],qr[1];
# h qr[0];
# cx qr[2],qr[0];
# tdg qr[0];
# cx qr[2],qr[0];
# t qr[0];
# t qr[2];
# h qr[0];
# cx qr[0],qr[1];
# t qr[1];
# t qr[0];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# t qr[1];
# t qr[3];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# h qr[0];
# h qr[1];
# t qr[1];
# tdg qr[3];
# t qr[2];
# cx qr[3],qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# t qr[3];
# tdg qr[1];
# cx qr[2],qr[3];
# tdg qr[3];
# t qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# cx qr[3],qr[2];
# h qr[1];
# measure qr[1] -> cr[1];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];

# %%
#other way complire and run:
job = execute(qc, backend='local_qasm_simulator', shots=1024, max_credits=3)

lapse = 0
interval = 5
while not job.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job.status)
    time.sleep(interval)
    lapse += 1
print(job.status)

print(job.result().get_counts(qc))
plot_histogram(job.result().get_counts(qc))
# Out:
# Status @ 0 seconds
# {'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': None}
# {'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': None}
# {'0000': 487, '1110': 537}

# %%
#the circuit running is not the one we write
qobj = compile(qc, backend='local_qasm_simulator')

qasm_str = qp.get_compiled_qasm(qobj, 'Circuit')

qasm_circ = qiskit.load_qasm_string(qasm_str);
circuit_drawer(qasm_circ)
# Out:
# <PIL.Image.Image image mode=RGB size=10598x440 at 0x7F618C21AFD0>

# %%
print(qasm_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[4];
# creg cr[4];
# h qr[3];
# cx qr[3],qr[2];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# u1(0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[2];
# h qr[0];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[1],qr[0];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# h qr[0];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[2];
# u1(0.785398163397448) qr[0];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[2];
# u1(-0.785398163397448) qr[3];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# h qr[0];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[1];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[1];
# cx qr[0],qr[1];
# h qr[0];
# cx qr[2],qr[0];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[0];
# u1(0.785398163397448) qr[0];
# u1(0.785398163397448) qr[2];
# h qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[3];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# h qr[0];
# h qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[3],qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[1];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# cx qr[3],qr[2];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[3];
# cx qr[3],qr[2];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[2];
# h qr[0];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[1],qr[0];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# h qr[0];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[2];
# u1(0.785398163397448) qr[0];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[3],qr[2];
# cx qr[0],qr[3];
# h qr[0];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[1];
# cx qr[0],qr[3];
# cx qr[3],qr[1];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[1];
# cx qr[0],qr[1];
# h qr[0];
# cx qr[2],qr[0];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[0];
# u1(0.785398163397448) qr[0];
# u1(0.785398163397448) qr[2];
# h qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[3];
# cx qr[3],qr[1];
# cx qr[0],qr[3];
# h qr[0];
# h qr[1];
# u1(0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[3],qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# u1(0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[1];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[1],qr[3];
# cx qr[2],qr[1];
# cx qr[3],qr[2];
# h qr[1];
# measure qr[1] -> cr[1];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];

# %% [markdown]
# # Running on a real device

# %%
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['operational'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

backend = lowest_pending_jobs()
print("The best backend is " + backend)
# Out:
# The best backend is ibmqx5

# %%
backend= 'ibmqx4'
api.backend_status(backend)
# Out:
# {'available': True, 'backend': 'ibmqx4', 'pending_jobs': 267}

# %%
api.backend_calibration(backend)
# Out:
# {'backend': 'ibmqx4',
#  'lastUpdateDate': '2018-08-17T10:00:20.000Z',
#  'multiQubitGates': [{'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.04384724580129881},
#    'name': 'CX1_0',
#    'qubits': [1, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-17T10:00:20Z', 'value': 0.05606104489580127},
#    'name': 'CX2_0',
#    'qubits': [2, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.036173068020120436},
#    'name': 'CX2_1',
#    'qubits': [2, 1],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.056823634317806654},
#    'name': 'CX3_2',
#    'qubits': [3, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-17T10:00:20Z', 'value': 0.0433663907690201},
#    'name': 'CX3_4',
#    'qubits': [3, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-17T10:00:20Z', 'value': 0.05779480980995047},
#    'name': 'CX4_2',
#    'qubits': [4, 2],
#    'type': 'CX'}],
#  'qubits': [{'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.002662115274625232},
#    'name': 'Q0',
#    'readoutError': {'date': '2018-08-17T10:00:20Z', 'value': 0.129}},
#   {'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.001803112096824766},
#    'name': 'Q1',
#    'readoutError': {'date': '2018-08-17T10:00:20Z', 'value': 0.051}},
#   {'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.001545458810288558},
#    'name': 'Q2',
#    'readoutError': {'date': '2018-08-17T10:00:20Z', 'value': 0.019}},
#   {'gateError': {'date': '2018-08-17T10:00:20Z',
#     'value': 0.0014595792651160289},
#    'name': 'Q3',
#    'readoutError': {'date': '2018-08-17T10:00:20Z', 'value': 0.016}},
#   {'gateError': {'date': '2018-08-17T10:00:20Z', 'value': 0.00128782749692391},
#    'name': 'Q4',
#    'readoutError': {'date': '2018-08-17T10:00:20Z', 'value': 0.043}}]}

# %%
api.backend_parameters(backend)
# Out:
# {'backend': 'ibmqx4',
#  'fridgeParameters': {'Temperature': {'date': '-', 'unit': '-', 'value': []},
#   'cooldownDate': '2017-09-07'},
#  'lastUpdateDate': '2018-08-17T10:00:20.000Z',
#  'qubits': [{'T1': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'µs',
#     'value': 8.8},
#    'T2': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 15.7},
#    'buffer': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'GHz',
#     'value': 5.24985},
#    'gateTime': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q0'},
#   {'T1': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 42.5},
#    'T2': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 25.7},
#    'buffer': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'GHz',
#     'value': 5.2958},
#    'gateTime': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q1'},
#   {'T1': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 42.4},
#    'T2': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 41.5},
#    'buffer': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'GHz',
#     'value': 5.35321},
#    'gateTime': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q2'},
#   {'T1': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 61.4},
#    'T2': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 28},
#    'buffer': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'GHz',
#     'value': 5.43499},
#    'gateTime': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q3'},
#   {'T1': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 55.9},
#    'T2': {'date': '2018-08-17T10:00:20Z', 'unit': 'µs', 'value': 12.7},
#    'buffer': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-17T10:00:20Z',
#     'unit': 'GHz',
#     'value': 5.17585},
#    'gateTime': {'date': '2018-08-17T10:00:20Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q4'}]}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
print(qs_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[4];
# creg cr[4];
# u2(0,3.14159265358979) q[3];
# u1(-0.785398163397448) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[3],q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.92699081698724) q[3];
# u1(-0.785398163397448) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,2.35619449019234) q[0];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.92699081698724) q[2];
# cx q[2],q[0];
# u1(-0.785398163397448) q[0];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# cx q[2],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[3],q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[2],q[1];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[3];
# barrier q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# cx q[2],q[0];
# u1(0.785398163397448) q[2];
# u1(0.785398163397448) q[0];
# cx q[3],q[2];
# u1(-0.785398163397448) q[3];
# cx q[2],q[0];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[1];
# u2(1.57079632679490,3.14159265358979) q[1];
# u3(1.57079632679490,0.785398163397448,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,2.35619449019234) q[3];
# cx q[2],q[0];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# cx q[2],q[0];
# barrier q[0];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[1];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.92699081698724) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u1(-0.785398163397448) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.92699081698724) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[2],q[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u2(0,2.35619449019234) q[2];
# u1(0.785398163397448) q[1];
# cx q[2],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u2(0,3.92699081698724) q[1];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# cx q[3],q[2];
# u1(0.785398163397448) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[2],q[1];
# u1(0.785398163397448) q[2];
# u2(0,2.35619449019234) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[2],q[0];
# u2(0,3.92699081698724) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[2];
# barrier q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[1];
# u2(1.57079632679490,3.14159265358979) q[1];
# u3(1.57079632679490,0.785398163397448,3.14159265358979) q[2];
# cx q[3],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# cx q[3],q[2];
# u1(0.785398163397448) q[0];
# u1(0.785398163397448) q[2];
# cx q[2],q[0];
# cx q[3],q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[3];
# u1(-0.785398163397448) q[2];
# cx q[2],q[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,2.35619449019234) q[0];
# u2(0,3.14159265358979) q[1];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[1];
# u2(0.785398163397448,3.14159265358979) q[1];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# measure q[0] -> cr[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[1];
# measure q[2] -> cr[3];
# measure q[1] -> cr[2];

# %%
shots=1024
max_credits=3
job_exp = execute(qc, backend=backend, shots=shots, max_credits=max_credits)

lapse = 0
interval = 10
while not job_exp.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job_exp.status)
    time.sleep(interval)
    lapse += 1
print(job_exp.status)
# Out:
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 10 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 268}
# Status @ 20 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 268}
# Status @ 30 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 267}
# Status @ 40 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 267}
# Status @ 50 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 266}
# Status @ 60 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 266}
# Status @ 70 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 266}
# Status @ 80 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 265}
# Status @ 90 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 264}
# Status @ 100 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 264}
# Status @ 110 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 263}
# Status @ 120 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 262}
# Status @ 130 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 262}
# Status @ 140 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 261}
# Status @ 150 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 261}
# Status @ 160 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 259}
# Status @ 170 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 259}
# Status @ 180 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 259}
# Status @ 190 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 200 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 258}
# Status @ 210 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 258}
# Status @ 220 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 230 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 240 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 250 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 260 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 270 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 257}
# Status @ 280 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 256}
# Status @ 290 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 300 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 256}
# Status @ 310 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 256}
# Status @ 320 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 256}
# Status @ 330 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 256}
# Status @ 340 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 350 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 255}
# Status @ 360 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 370 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 255}
# Status @ 380 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 254}
# Status @ 390 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 254}
# Status @ 400 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 253}
# Status @ 410 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 420 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 430 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 440 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 450 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 460 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 470 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 480 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 490 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 252}
# Status @ 500 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 510 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 520 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 530 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 540 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 550 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 560 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 570 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 580 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 251}
# Status @ 590 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 250}
# Status @ 600 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 250}
# Status @ 610 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 249}
# Status @ 620 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 249}
# Status @ 630 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 249}
# Status @ 640 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 248}
# Status @ 650 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 248}
# Status @ 660 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 248}
# Status @ 670 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 248}
# Status @ 680 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 247}
# Status @ 690 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 247}
# Status @ 700 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 710 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 247}
# Status @ 720 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position':
seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3530 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3540 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3550 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3560 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3570 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3580 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3590 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 211}
# Status @ 3600 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3610 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3620 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3630 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3640 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3650 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3660 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3670 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3680 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 210}
# Status @ 3690 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3700 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3710 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3720 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3730 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3740 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3750 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3760 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3770 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3780 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 209}
# Status @ 3790 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3800 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3810 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3820 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3830 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3840 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3850 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3860 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3870 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3880 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 208}
# Status @ 3890 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3900 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3910 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3920 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3930 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3940 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3950 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3960 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3970 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 207}
# Status @ 3980 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 206}
# Status @ 3990 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 205}
# Status @ 4000 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 205}
# Status @ 4010 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 202}
# Status @ 4020 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 202}
# Status @ 4030 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 200}
# Status @ 4040 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 200}
# Status @ 4050 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 200}
# Status @ 4060 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 199}
# Status @ 4070 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 199}
# Status @ 4080 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 199}
# Status @ 4090 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 199}
# Status @ 4100 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4110 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4120 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4130 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4140 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4150 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4160 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4170 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4180 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 197}
# Status @ 4190 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4200 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4210 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4220 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4230 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4240 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4250 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 196}
# Status @ 4260 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4270 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4280 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4290 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4300 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 195}
# Status @ 4310 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4320 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4330 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 4340 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 4350 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 4360 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4370 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4380 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 4390 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 4400 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 4410 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 4420 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 4430 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4440 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 4450 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 4460 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 4470 seconds
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# {'job_id': '5b773a70d529a2003b85652d', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}

# %%
plot_histogram(job_exp.result().get_counts(qc))

# %%
job_exp.result().get_data('Circuit')
# Out:
# {'counts': {'0000': 214,
#   '0010': 122,
#   '0100': 129,
#   '0110': 185,
#   '1000': 120,
#   '1010': 67,
#   '1100': 121,
#   '1110': 66},
#  'date': '2018-08-17T23:02:59.406Z',
#  'time': 25.34206795692444}
