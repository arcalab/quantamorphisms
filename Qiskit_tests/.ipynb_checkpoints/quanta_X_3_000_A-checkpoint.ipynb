# %% [markdown]
# # matrix fold of gate X - adaptation to qiskit

# %%
# Checking the version of PYTHON; we only support > 3.5
import sys
sys.path.append('../../../Transferências/qiskit-sdk-py-master')

if sys.version_info < (3,5):
    raise Exception('Please use Python version 3.5 or greater.')

import qiskit
import numpy

# Import the QISKit
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QuantumProgram, Result
from qiskit import available_backends, execute, register, get_backend
import getpass, time
import Qconfig
from qiskit import compile


# import basic plot tools
from qiskit.tools.visualization import plot_histogram, circuit_drawer, plot_state

#information of API
from IBMQuantumExperience import IBMQuantumExperience

# Import tomography tools
import qiskit.tools.qcvv.tomography as tomo

# Aditional packages
from qiskit.tools.qi.qi import *

# %%
api = IBMQuantumExperience(Qconfig.APItoken)
myCredits = api.get_my_credits()

print(myCredits)

# set the APIToken and API url
try:
    register(Qconfig.APItoken,Qconfig.config['url'])

    print('\nYou have access to great power!')
    print(available_backends({'local': False, 'simulator': False}))
    print('Available simulators:')
    print(available_backends({'simulator':True}))
except: 
    print('Something went wrong.\nDid you enter a correct token?')
# Out:
# {'promotional': 0, 'remaining': 15, 'maxUserType': 15}
#
# You have access to great power!
# ['ibmq_16_rueschlikon', 'ibmq_5_tenerife', 'ibmq_5_yorktown']
# Available simulators:
# ['ibmq_qasm_simulator', 'local_qasm_simulator', 'local_statevector_simulator', 'local_unitary_simulator']

# %%
# Creating Programs
# create QuantumProgram object instance.
qp = QuantumProgram()

# Creating Registers
# create Quantum Register called "qr" with 3 qubits 
qr = qp.create_quantum_register('qr', 3)
# create Classical Register  called "cr" with 3 bits
cr = qp.create_classical_register('cr', 3)

# Creating Circuits
# create Quantum Circuit called "qc" involving your Quantum Register "qr"
# and your Classical Register "cr"
qc = qp.create_circuit('Circuit', [qr], [cr])

# %%
# Get the components.

# get the circuit by Name
circuit = qp.get_circuit('Circuit')

# get the Quantum Register by Name
quantum_r = qp.get_quantum_register('qr')

# get the Classical Register by Name
classical_r = qp.get_classical_register('cr')

# %%
#preparing qubits

# the circuit we want:
qc.ccx(qr[2],qr[1],qr[0])
qc.x(qr[2])
qc.ccx(qr[2],qr[1],qr[0])
qc.x(qr[2])

# %%
circuit_drawer(qc)
# Out:
# <PIL.Image.Image image mode=RGB size=383x260 at 0x7F0C4FB1B358>

# %%
job = execute(qc, backend='local_unitary_simulator')
np.round(job.result().get_data(qc)['unitary'], 3)
# Out:
# array([[ 1.-0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j, -0.-0.j,  0.+0.j,
#          0.+0.j],
#        [ 0.+0.j,  1.-0.j,  0.+0.j,  0.+0.j, -0.-0.j,  0.+0.j,  0.+0.j,
#          0.+0.j],
#        [ 0.+0.j,  0.+0.j,  0.+0.j,  1.-0.j,  0.+0.j,  0.+0.j, -0.+0.j,
#          0.-0.j],
#        [ 0.+0.j,  0.+0.j,  1.-0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.-0.j,
#         -0.+0.j],
#        [-0.+0.j,  0.-0.j,  0.+0.j,  0.+0.j,  1.-0.j, -0.+0.j,  0.+0.j,
#          0.+0.j],
#        [ 0.-0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,  1.-0.j,  0.+0.j,
#          0.+0.j],
#        [ 0.+0.j,  0.+0.j,  0.-0.j, -0.+0.j,  0.+0.j,  0.+0.j,  0.+0.j,
#          1.-0.j],
#        [ 0.+0.j,  0.+0.j, -0.+0.j,  0.-0.j,  0.+0.j,  0.+0.j,  1.-0.j,
#         -0.+0.j]])

# %%
qc.measure(qr[0], cr[0])
qc.measure(qr[1], cr[1])
qc.measure(qr[2], cr[2])

circuit_drawer(qc)
# Out:
# <PIL.Image.Image image mode=RGB size=617x277 at 0x7F0C4F207B70>

# %%
qp.get_circuit_names()
# Out:
# ['Circuit']

# %%
# QASM from a program

QASM_source = qp.get_qasm('Circuit')

print(QASM_source)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[3];
# creg cr[3];
# ccx qr[2],qr[1],qr[0];
# x qr[2];
# ccx qr[2],qr[1],qr[0];
# x qr[2];
# measure qr[0] -> cr[0];
# measure qr[1] -> cr[1];
# measure qr[2] -> cr[2];

# %%
backend = 'local_qasm_simulator' 
circuits = ['Circuit']  # Group of circuits to execute

# %%
qobj=qp.compile(circuits, backend) # Compile program

# %%
result = qp.run(qobj, timeout=240) #run program
print(result)
# Out:
# COMPLETED

# %%
result.get_counts('Circuit')
# Out:
# {'000': 1024}

# %%
#other way complire and run:
job = execute(qc, backend='local_qasm_simulator', shots=1024, max_credits=3)

lapse = 0
interval = 5
while not job.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job.status)
    time.sleep(interval)
    lapse += 1
print(job.status)

print(job.result().get_counts(qc))
plot_histogram(job.result().get_counts(qc))
# Out:
# Status @ 0 seconds
# {'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': None}
# {'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': None}
# {'000': 1024}

# %%
#the circuit running is not the one we write
qobj = compile(qc, backend='local_qasm_simulator')

qasm_str = qp.get_compiled_qasm(qobj, 'Circuit')

qasm_circ = qiskit.load_qasm_string(qasm_str);
circuit_drawer(qasm_circ)
# Out:
# <PIL.Image.Image image mode=RGB size=1922x296 at 0x7F4DF0512160>

# %%
print(qasm_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[3];
# creg cr[3];
# h qr[0];
# cx qr[1],qr[0];
# tdg qr[0];
# cx qr[2],qr[0];
# t qr[0];
# cx qr[1],qr[0];
# t qr[1];
# tdg qr[0];
# cx qr[2],qr[0];
# cx qr[2],qr[1];
# tdg qr[1];
# t qr[2];
# cx qr[2],qr[1];
# x qr[2];
# t qr[0];
# h qr[0];
# h qr[0];
# cx qr[1],qr[0];
# tdg qr[0];
# cx qr[2],qr[0];
# t qr[0];
# cx qr[1],qr[0];
# t qr[1];
# tdg qr[0];
# cx qr[2],qr[0];
# cx qr[2],qr[1];
# tdg qr[1];
# t qr[2];
# cx qr[2],qr[1];
# x qr[2];
# measure qr[1] -> cr[1];
# measure qr[2] -> cr[2];
# t qr[0];
# h qr[0];
# measure qr[0] -> cr[0];

# %% [markdown]
# # Running on a real device

# %%
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['operational'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

backend = lowest_pending_jobs()
print("The best backend is " + backend)
# Out:
# The best backend is ibmqx5

# %%
backend = 'ibmqx4'

api.backend_status(backend)
# Out:
# {'available': True, 'backend': 'ibmqx4', 'pending_jobs': 46}

# %%
api.backend_calibration(backend)
# Out:
# {'backend': 'ibmqx4',
#  'lastUpdateDate': '2018-07-23T09:57:24.000Z',
#  'multiQubitGates': [{'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.031806302469344405},
#    'name': 'CX1_0',
#    'qubits': [1, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.022841470582157963},
#    'name': 'CX2_0',
#    'qubits': [2, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-07-23T09:57:24Z', 'value': 0.03719846065895152},
#    'name': 'CX2_1',
#    'qubits': [2, 1],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-07-23T09:57:24Z', 'value': 0.07736410019262938},
#    'name': 'CX3_2',
#    'qubits': [3, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-07-23T09:57:24Z', 'value': 0.04474069696423133},
#    'name': 'CX3_4',
#    'qubits': [3, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-07-23T09:57:24Z', 'value': 0.04687352229446365},
#    'name': 'CX4_2',
#    'qubits': [4, 2],
#    'type': 'CX'}],
#  'qubits': [{'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.0009443532335046134},
#    'name': 'Q0',
#    'readoutError': {'date': '2018-07-23T09:57:24Z', 'value': 0.038}},
#   {'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.0017172252255832077},
#    'name': 'Q1',
#    'readoutError': {'date': '2018-07-23T09:57:24Z', 'value': 0.041}},
#   {'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.0009443532335046134},
#    'name': 'Q2',
#    'readoutError': {'date': '2018-07-23T09:57:24Z', 'value': 0.02}},
#   {'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.0014595792651160289},
#    'name': 'Q3',
#    'readoutError': {'date': '2018-07-23T09:57:24Z', 'value': 0.021}},
#   {'gateError': {'date': '2018-07-23T09:57:24Z',
#     'value': 0.0011160854878761173},
#    'name': 'Q4',
#    'readoutError': {'date': '2018-07-23T09:57:24Z', 'value': 0.044}}]}

# %%
api.backend_parameters(backend)
# Out:
# {'backend': 'ibmqx4',
#  'fridgeParameters': {'Temperature': {'date': '-', 'unit': '-', 'value': []},
#   'cooldownDate': '2017-09-07'},
#  'lastUpdateDate': '2018-07-23T09:57:24.000Z',
#  'qubits': [{'T1': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'µs',
#     'value': 47.2},
#    'T2': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 46.3},
#    'buffer': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'GHz',
#     'value': 5.24985},
#    'gateTime': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q0'},
#   {'T1': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 47.1},
#    'T2': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 17},
#    'buffer': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'GHz',
#     'value': 5.29575},
#    'gateTime': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q1'},
#   {'T1': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 38.6},
#    'T2': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 50.3},
#    'buffer': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'GHz',
#     'value': 5.35321},
#    'gateTime': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q2'},
#   {'T1': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 57.8},
#    'T2': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 31.5},
#    'buffer': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'GHz',
#     'value': 5.43504},
#    'gateTime': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q3'},
#   {'T1': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 50.2},
#    'T2': {'date': '2018-07-23T09:57:24Z', 'unit': 'µs', 'value': 14.1},
#    'buffer': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-07-23T09:57:24Z',
#     'unit': 'GHz',
#     'value': 5.17585},
#    'gateTime': {'date': '2018-07-23T09:57:24Z', 'unit': 'ns', 'value': 60},
#    'name': 'Q4'}]}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
# Out:
# <PIL.Image.Image image mode=RGB size=3235x326 at 0x7F4DF02CF208>

# %%
print(qs_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[3];
# creg cr[3];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u1(0.785398163397448) q[1];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# cx q[2],q[1];
# u1(7.06858347057703) q[0];
# u1(0.785398163397448) q[2];
# u1(-0.785398163397448) q[1];
# cx q[2],q[1];
# u3(3.14159265358979,0,3.14159265358979) q[2];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u1(0.785398163397448) q[1];
# u1(-0.785398163397448) q[0];
# cx q[2],q[0];
# cx q[2],q[1];
# u2(0,3.92699081698724) q[0];
# u1(0.785398163397448) q[2];
# u1(-0.785398163397448) q[1];
# cx q[2],q[1];
# measure q[0] -> cr[0];
# u3(3.14159265358979,0,3.14159265358979) q[2];
# measure q[1] -> cr[1];
# measure q[2] -> cr[2];

# %%
shots=1024
max_credits=3
job_exp = execute(qc, backend=backend, shots=shots, max_credits=max_credits)

lapse = 0
interval = 10
while not job_exp.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job_exp.status)
    time.sleep(interval)
    lapse += 1
print(job_exp.status)
# Out:
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 10 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 20 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 30 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 40 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 50 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 60 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 70 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 80 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 90 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 100 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 110 seconds
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5b55bfc88e405d00383f3441', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}

# %%
plot_histogram(job_exp.result().get_counts(qc))

# %%
job_exp.result().get_data('Circuit')
# Out:
# {'counts': {'000': 685,
#   '001': 126,
#   '010': 57,
#   '011': 62,
#   '100': 51,
#   '101': 19,
#   '110': 22,
#   '111': 2},
#  'date': '2018-07-23T11:47:29.915Z',
#  'time': 25.351712942123413}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
