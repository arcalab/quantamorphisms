# %% [markdown]
# # matrix fold of gate XOR adapted to qiskit

# %%
# Checking the version of PYTHON; we only support > 3.5
import sys
sys.path.append('../../../Transferências/qiskit-sdk-py-master')

if sys.version_info < (3,5):
    raise Exception('Please use Python version 3.5 or greater.')

import qiskit
import numpy

# Import the QISKit
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QuantumProgram, Result
from qiskit import available_backends, execute, register, get_backend
import getpass, time
import Qconfig_x2_4_5 as Qconfig
from qiskit import compile


# import basic plot tools
from qiskit.tools.visualization import plot_histogram, circuit_drawer, plot_state

#information of API
from IBMQuantumExperience import IBMQuantumExperience

# Import tomography tools
import qiskit.tools.qcvv.tomography as tomo

# Aditional packages
from qiskit.tools.qi.qi import *

# %%
api = IBMQuantumExperience(Qconfig.APItoken)
myCredits = api.get_my_credits()

print(myCredits)

# set the APIToken and API url
try:
    register(Qconfig.APItoken,Qconfig.config['url'])

    print('\nYou have access to great power!')
    print(available_backends({'local': False, 'simulator': False}))
    print('Available simulators:')
    print(available_backends({'simulator':True}))
except: 
    print('Something went wrong.\nDid you enter a correct token?')
# Out:
# {'maxUserType': 15, 'promotional': 0, 'remaining': 12}
#
# You have access to great power!
# ['ibmq_16_rueschlikon', 'ibmq_5_tenerife', 'ibmq_5_yorktown']
# Available simulators:
# ['ibmq_qasm_simulator', 'local_qasm_simulator', 'local_statevector_simulator', 'local_unitary_simulator']

# %%
# Creating Programs
# create QuantumProgram object instance.
qp = QuantumProgram()

# Creating Registers
# create Quantum Register called "qr" with 7 qubits 
qr = qp.create_quantum_register('qr', 7)
# create Classical Register  called "cr" with 7 bits
cr = qp.create_classical_register('cr', 7)

# Creating Circuits
# create Quantum Circuit called "qc" involving your Quantum Register "qr"
# and your Classical Register "cr"
qc = qp.create_circuit('Circuit', [qr], [cr])

# %%
# Get the components.

# get the circuit by Name
circuit = qp.get_circuit('Circuit')

# get the Quantum Register by Name
quantum_r = qp.get_quantum_register('qr')

# get the Classical Register by Name
classical_r = qp.get_classical_register('cr')

# %%
#preparing qubits
qc.h(qr[2])


# the circuit we want:
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.tdg(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.t(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.tdg(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.t(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])

# don't forget update the number of qubits and bits registered

# %%
circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
qc.barrier(qr[2])
qc.barrier(qr[3])
qc.barrier(qr[4])
qc.barrier(qr[5])
qc.barrier(qr[6])

qc.measure(qr[2],cr[2])
qc.measure(qr[3],cr[3])
qc.measure(qr[4],cr[4])
qc.measure(qr[5],cr[5])
qc.measure(qr[6],cr[6])

circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
qp.get_circuit_names()
# Out:
# ['Circuit']

# %%
# QASM from a program

QASM_source = qp.get_qasm('Circuit')

print(QASM_source)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# h qr[2];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# tdg qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# t qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# tdg qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# t qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[2];
# barrier qr[3];
# barrier qr[4];
# barrier qr[5];
# barrier qr[6];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];
# measure qr[4] -> cr[4];
# measure qr[5] -> cr[5];
# measure qr[6] -> cr[6];

# %%
#other way complire and run:
job = execute(qc, backend='local_qasm_simulator', shots=1024, max_credits=3)

lapse = 0
interval = 5
while not job.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job.status)
    time.sleep(interval)
    lapse += 1
print(job.status)

print(job.result().get_counts(qc))
plot_histogram(job.result().get_counts(qc))
# Out:
# Status @ 0 seconds
# {'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': None}
# {'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': None}
# {'0000000': 493, '0000100': 531}

# %%
#the circuit running is not the one we write
qobj = compile(qc, backend='local_qasm_simulator')

qasm_str = qp.get_compiled_qasm(qobj, 'Circuit')

qasm_circ = qiskit.load_qasm_string(qasm_str);
circuit_drawer(qasm_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
print(qasm_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# h qr[2];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[2];
# barrier qr[3];
# barrier qr[4];
# barrier qr[5];
# barrier qr[6];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];
# measure qr[4] -> cr[4];
# measure qr[5] -> cr[5];
# measure qr[6] -> cr[6];

# %% [markdown]
# # Running on real device

# %%
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['operational'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

backend = lowest_pending_jobs()
print("The best backend is " + backend)
# Out:
# The best backend is ibmqx4

# %%
#to this case we need ibmqx5 - 16 qubits
backend = 'ibmqx5'
api.backend_status(backend)
# Out:
# {'available': True, 'backend': 'ibmqx5', 'pending_jobs': 34}

# %%
api.backend_calibration(backend)
# Out:
# {'backend': 'ibmqx5',
#  'lastUpdateDate': '2018-09-20T11:39:09.000Z',
#  'multiQubitGates': [{'gateError': {'date': '2018-09-20T11:06:49Z',
#     'value': 0.035272399973318325},
#    'name': 'CX1_0',
#    'qubits': [1, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.04103517889971284},
#    'name': 'CX1_2',
#    'qubits': [1, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z',
#     'value': 0.036492083099913974},
#    'name': 'CX2_3',
#    'qubits': [2, 3],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03922244688221865},
#    'name': 'CX3_4',
#    'qubits': [3, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.05580061416505083},
#    'name': 'CX3_14',
#    'qubits': [3, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z',
#     'value': 0.032966150369984404},
#    'name': 'CX5_4',
#    'qubits': [5, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.03580840007398786},
#    'name': 'CX6_5',
#    'qubits': [6, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03311083762712183},
#    'name': 'CX6_7',
#    'qubits': [6, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.04769211884706656},
#    'name': 'CX6_11',
#    'qubits': [6, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03985139654393477},
#    'name': 'CX7_10',
#    'qubits': [7, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.04278165446343182},
#    'name': 'CX8_7',
#    'qubits': [8, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z',
#     'value': 0.034687160175718795},
#    'name': 'CX9_8',
#    'qubits': [9, 8],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z',
#     'value': 0.035529053877761146},
#    'name': 'CX9_10',
#    'qubits': [9, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.02978366406213062},
#    'name': 'CX11_10',
#    'qubits': [11, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.04588437304942397},
#    'name': 'CX12_5',
#    'qubits': [12, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.05007238571544248},
#    'name': 'CX12_11',
#    'qubits': [12, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.04065486284816375},
#    'name': 'CX12_13',
#    'qubits': [12, 13],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03680305318159474},
#    'name': 'CX13_4',
#    'qubits': [13, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:39:09Z', 'value': 0.05811638365390015},
#    'name': 'CX13_14',
#    'qubits': [13, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03888379452821489},
#    'name': 'CX15_0',
#    'qubits': [15, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.03619942546528812},
#    'name': 'CX15_2',
#    'qubits': [15, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-09-20T11:06:49Z', 'value': 0.04771551037821162},
#    'name': 'CX15_14',
#    'qubits': [15, 14],
#    'type': 'CX'}],
#  'qubits': [{'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.002329214570565341},
#    'name': 'Q0',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.06289999999999996}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0033567350959923803},
#    'name': 'Q1',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.06740000000000002}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.002883422107100131},
#    'name': 'Q2',
#    'readoutError': {'date': '2018-09-20T10:23:56Z', 'value': 0.1008}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0022691399776315624},
#    'name': 'Q3',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.043200000000000016}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0016448629415709015},
#    'name': 'Q4',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.07030000000000003}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0018894813912234687},
#    'name': 'Q5',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.05069999999999997}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0021046537498818907},
#    'name': 'Q6',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.05149999999999999}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0018358664155457283},
#    'name': 'Q7',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.04400000000000004}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.001809226738295644},
#    'name': 'Q8',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.04569999999999996}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0011601161786518044},
#    'name': 'Q9',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.09559999999999991}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0012707974107276088},
#    'name': 'Q10',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.07369999999999999}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.002663016259206008},
#    'name': 'Q11',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.048799999999999955}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0021115884691486064},
#    'name': 'Q12',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.10850000000000004}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0021946354444967175},
#    'name': 'Q13',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.03649999999999998}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.001960075446788001},
#    'name': 'Q14',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.07179999999999997}},
#   {'gateError': {'date': '2018-09-20T10:31:16Z',
#     'value': 0.0029026264273667723},
#    'name': 'Q15',
#    'readoutError': {'date': '2018-09-20T10:23:56Z',
#     'value': 0.10189999999999999}}]}

# %%
api.backend_parameters(backend)
# Out:
# {'backend': 'ibmqx5',
#  'fridgeParameters': {'Temperature': {'date': '2018-09-20T03:48:24Z',
#    'unit': 'K',
#    'value': 0.0140007},
#   'cooldownDate': '2017-09-15'},
#  'lastUpdateDate': '2018-09-20T10:25:25.000Z',
#  'qubits': [{'T1': {'date': '2018-09-20T10:24:23Z',
#     'unit': 'µs',
#     'value': 45.2},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 30.4},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.2559419},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q0'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 40.2},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 63.1},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.3960328},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q1'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 27},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 53.8},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.2757184},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q2'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 48.5},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 77.8},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.0830881},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q3'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 48.3},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 71},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 4.9791894},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q4'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 47.1},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 45.2},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.151492},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q5'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 51.6},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 79.4},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.3058128},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q6'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 41.4},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 64.9},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.2523717},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q7'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 23.2},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 55.1},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.1152031},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q8'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 60.5},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 77.3},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.1554205},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q9'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 62.9},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 93.7},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.0425578},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q10'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 39.7},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 48.6},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.110877},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q11'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 43},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 50},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 4.9468382},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q12'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 52.3},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 80.9},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.0882587},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q13'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 30.3},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 60.6},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 4.870487},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q14'},
#   {'T1': {'date': '2018-09-20T10:24:23Z', 'unit': 'µs', 'value': 47.8},
#    'T2': {'date': '2018-09-20T10:25:25Z', 'unit': 'µs', 'value': 93.9},
#    'buffer': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-09-20T10:05:23Z',
#     'units': 'GHz',
#     'value': 5.1047435},
#    'gateTime': {'date': '2018-09-20T10:05:23Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q15'}]}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fc9434efea0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.local/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x170546 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x170546 pixels is too large. It must be less than 2^16 in each direction.

# %%
print(qs_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[16];
# creg cr[7];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[13],q[14];
# cx q[1],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[15];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(0.785398163397448) q[14];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u1(0.785398163397448) q[13];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# cx q[3],q[14];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(-0.785398163397448,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# barrier q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# barrier q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u1(0.785398163397448) q[3];
# cx q[2],q[3];
# cx q[3],q[14];
# u1(-0.785398163397448) q[2];
# u1(-0.785398163397448) q[14];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[1];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# cx q[1],q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(-0.785398163397448,3.14159265358979) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u1(0.785398163397448) q[13];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[14];
# cx q[3],q[14];
# u1(-0.785398163397448) q[14];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# cx q[3],q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# barrier q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u1(0.785398163397448) q[3];
# cx q[2],q[3];
# cx q[3],q[14];
# u1(-0.785398163397448) q[2];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# cx q[15],q[0];
# u1(-0.785398163397448) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.92699081698724) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,2.35619449019234) q[3];
# u1(-0.785398163397448) q[2];
# cx q[15],q[2];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[3];
# u2(0,2.35619449019234) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u1(-0.785398163397448) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# barrier q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# u2(0,3.92699081698724) q[1];
# cx q[1],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.92699081698724) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.92699081698724) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[15],q[2];
# cx q[3],q[14];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[14];
# u1(0.785398163397448) q[3];
# u1(-0.785398163397448) q[2];
# cx q[2],q[3];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0,2.35619449019234) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[1];
# u2(0,3.14159265358979) q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[0];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,2.35619449019234) q[3];
# u1(-0.785398163397448) q[2];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[1],q[0];
# u2(0,2.35619449019234) q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# barrier q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,2.35619449019234) q[1];
# u1(0.785398163397448) q[0];
# cx q[1],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.92699081698724) q[3];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(0.785398163397448) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# barrier q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,2.35619449019234) q[15];
# u1(0.785398163397448) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# cx q[1],q[2];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[3];
# u2(0,2.35619449019234) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u1(0.785398163397448) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# barrier q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,2.35619449019234) q[15];
# u1(0.785398163397448) q[0];
# cx q[15],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[15],q[0];
# cx q[15],q[2];
# u1(0.785398163397448) q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# cx q[1],q[0];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# u1(0.785398163397448) q[1];
# u1(-0.785398163397448) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[13];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u1(-0.785398163397448) q[2];
# u2(0,3.92699081698724) q[14];
# cx q[1],q[2];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# barrier q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# u2(0,2.35619449019234) q[1];
# cx q[1],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[3];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# barrier q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# barrier q[2];
# measure q[2] -> cr[4];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# measure q[1] -> cr[3];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# measure q[13] -> cr[2];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# u2(0,3.92699081698724) q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# barrier q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# measure q[14] -> cr[5];
# barrier q[0];
# measure q[0] -> cr[6];

# %%
shots=1024
max_credits=3
job_exp = execute(qc, backend=backend, shots=shots, max_credits=max_credits)

lapse = 0
interval = 10
while not job_exp.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job_exp.status)
    time.sleep(interval)
    lapse += 1
print(job_exp.status)
# Out:
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 10 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 20 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 30 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 40 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 50 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 60 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 70 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 80 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 90 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 100 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 110 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 34}
# Status @ 120 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 33}
# Status @ 130 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 32}
# Status @ 140 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 32}
# Status @ 150 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 31}
# Status @ 160 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 31}
# Status @ 170 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 30}
# Status @ 180 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 190 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 200 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 210 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 220 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 230 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 240 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 250 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 260 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 270 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 280 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 29}
# Status @ 290 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 28}
# Status @ 300 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 28}
# Status @ 310 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 27}
# Status @ 320 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 27}
# Status @ 330 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 340 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 350 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 360 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 370 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 380 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 390 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 400 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 410 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 420 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 430 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 26}
# Status @ 440 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 450 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 460 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 470 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 480 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 490 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 500 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 510 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 520 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 530 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 540 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 550 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 25}
# Status @ 560 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 570 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 580 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 590 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 600 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 610 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 620 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 630 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 640 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 650 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 660 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 670 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 24}
# Status @ 680 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 690 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 700 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 710 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 720 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 730 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 740 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 750 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 760 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 770 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 780 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 23}
# Status @ 790 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 800 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 810 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 820 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 830 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 840 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 850 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 860 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 870 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 880 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 890 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 900 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 22}
# Status @ 910 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 920 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 930 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 940 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 950 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 960 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 970 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 980 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 990 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 1000 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 1010 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 1020 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 1030 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 21}
# Status @ 1040 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 20}
# Status @ 1050 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 20}
# Status @ 1060 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 19}
# Status @ 1070 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 19}
# Status @ 1080 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 1090 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 18}
# Status @ 1100 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 17}
# Status @ 1110 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 16}
# Status @ 1120 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 16}
# Status @ 1130 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 1140 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 1150 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 14}
# Status @ 1160 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 14}
# Status @ 1170 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 13}
# Status @ 1180 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 13}
# Status @ 1190 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 1200 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 1210 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 11}
# Status @ 1220 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 10}
# Status @ 1230 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 10}
# Status @ 1240 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 1250 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 1260 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 8}
# Status @ 1270 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 8}
# Status @ 1280 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 7}
# Status @ 1290 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 7}
# Status @ 1300 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 1310 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 1320 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 5}
# Status @ 1330 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 4}
# Status @ 1340 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 4}
# Status @ 1350 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 1360 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 1370 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 1380 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1390 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1400 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1410 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1420 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1430 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1440 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1450 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1460 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1470 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1480 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1490 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1500 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1510 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1520 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1530 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1540 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1550 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1560 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1570 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1580 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1590 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1600 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1610 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1620 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1630 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1640 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1650 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1660 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1670 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1680 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1690 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1700 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 1710 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 1720 seconds
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# {'job_id': '5ba3c837170c4a0044c94802', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}

# %%
plot_histogram(job_exp.result().get_counts(qc))

# %%
job_exp.result().get_data('Circuit')
# Out:
# {'counts': {'0000000': 74,
#   '0000100': 29,
#   '0001000': 96,
#   '0001100': 45,
#   '0010000': 31,
#   '0010100': 30,
#   '0011000': 64,
#   '0011100': 31,
#   '0100000': 48,
#   '0100100': 25,
#   '0101000': 46,
#   '0101100': 40,
#   '0110000': 23,
#   '0110100': 18,
#   '0111000': 34,
#   '0111100': 26,
#   '1000000': 34,
#   '1000100': 20,
#   '1001000': 36,
#   '1001100': 23,
#   '1010000': 30,
#   '1010100': 18,
#   '1011000': 23,
#   '1011100': 15,
#   '1100000': 31,
#   '1100100': 18,
#   '1101000': 28,
#   '1101100': 20,
#   '1110000': 23,
#   '1110100': 13,
#   '1111000': 17,
#   '1111100': 15},
#  'date': '2018-09-20T16:58:10.753Z',
#  'time': 25.043001174926758}
