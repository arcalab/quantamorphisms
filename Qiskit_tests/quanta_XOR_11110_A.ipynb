# %% [markdown]
# # matrix fold of gate XOR adapted to qiskit

# %%
# Checking the version of PYTHON; we only support > 3.5
import sys
sys.path.append('../../../Transferências/qiskit-sdk-py-master')

if sys.version_info < (3,5):
    raise Exception('Please use Python version 3.5 or greater.')

import qiskit
import numpy

# Import the QISKit
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QuantumProgram, Result
from qiskit import available_backends, execute, register, get_backend
import getpass, time
import Qconfig
from qiskit import compile


# import basic plot tools
from qiskit.tools.visualization import plot_histogram, circuit_drawer, plot_state

#information of API
from IBMQuantumExperience import IBMQuantumExperience

# Import tomography tools
import qiskit.tools.qcvv.tomography as tomo

# Aditional packages
from qiskit.tools.qi.qi import *

# %%
api = IBMQuantumExperience(Qconfig.APItoken)
myCredits = api.get_my_credits()

print(myCredits)

# set the APIToken and API url
try:
    register(Qconfig.APItoken,Qconfig.config['url'])

    print('\nYou have access to great power!')
    print(available_backends({'local': False, 'simulator': False}))
    print('Available simulators:')
    print(available_backends({'simulator':True}))
except: 
    print('Something went wrong.\nDid you enter a correct token?')
# Out:
# {'maxUserType': 15, 'promotional': 0, 'remaining': 15}
#
# You have access to great power!
# ['ibmq_16_rueschlikon', 'ibmq_5_tenerife', 'ibmq_5_yorktown']
# Available simulators:
# ['ibmq_qasm_simulator', 'local_qasm_simulator', 'local_statevector_simulator', 'local_unitary_simulator']

# %%
# Creating Programs
# create QuantumProgram object instance.
qp = QuantumProgram()

# Creating Registers
# create Quantum Register called "qr" with 7 qubits 
qr = qp.create_quantum_register('qr', 7)
# create Classical Register  called "cr" with 7 bits
cr = qp.create_classical_register('cr', 7)

# Creating Circuits
# create Quantum Circuit called "qc" involving your Quantum Register "qr"
# and your Classical Register "cr"
qc = qp.create_circuit('Circuit', [qr], [cr])

# %%
# Get the components.

# get the circuit by Name
circuit = qp.get_circuit('Circuit')

# get the Quantum Register by Name
quantum_r = qp.get_quantum_register('qr')

# get the Classical Register by Name
classical_r = qp.get_classical_register('cr')

# %%
#preparing qubits
qc.x(qr[3])
qc.x(qr[4])
qc.x(qr[5])
qc.x(qr[6])


# the circuit we want:
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.tdg(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.t(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.tdg(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.t(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.t(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.tdg(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.t(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.t(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.tdg(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.t(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.t(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.tdg(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.tdg(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])
qc.barrier(qr[1])
qc.h(qr[1])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[6])
qc.t(qr[5])
qc.cx(qr[1],qr[6])
qc.cx(qr[6],qr[5])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[1],qr[5])
qc.h(qr[1])
qc.barrier(qr[0])
qc.h(qr[0])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[4])
qc.tdg(qr[3])
qc.cx(qr[0],qr[4])
qc.cx(qr[4],qr[3])
qc.tdg(qr[0])
qc.tdg(qr[3])
qc.cx(qr[0],qr[3])
qc.h(qr[0])
qc.h(qr[2])
qc.t(qr[2])
qc.t(qr[1])
qc.t(qr[0])
qc.cx(qr[1],qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.tdg(qr[1])
qc.t(qr[2])
qc.cx(qr[0],qr[1])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[2],qr[1])
qc.cx(qr[0],qr[2])
qc.cx(qr[1],qr[0])
qc.h(qr[2])
qc.h(qr[0])
qc.cx(qr[0],qr[3])
qc.t(qr[3])
qc.t(qr[0])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.t(qr[3])
qc.t(qr[4])
qc.cx(qr[4],qr[3])
qc.cx(qr[0],qr[4])
qc.h(qr[0])
qc.h(qr[1])
qc.cx(qr[1],qr[5])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.tdg(qr[5])
qc.t(qr[6])
qc.cx(qr[6],qr[5])
qc.cx(qr[1],qr[6])
qc.h(qr[1])

# don't forget update the number of qubits and bits registered

# %%
circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
qc.barrier(qr[2])
qc.barrier(qr[3])
qc.barrier(qr[4])
qc.barrier(qr[5])
qc.barrier(qr[6])

qc.measure(qr[2],cr[2])
qc.measure(qr[3],cr[3])
qc.measure(qr[4],cr[4])
qc.measure(qr[5],cr[5])
qc.measure(qr[6],cr[6])

circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
qp.get_circuit_names()
# Out:
# ['Circuit']

# %%
# QASM from a program

QASM_source = qp.get_qasm('Circuit')

print(QASM_source)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# x qr[3];
# x qr[4];
# x qr[5];
# x qr[6];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# tdg qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# t qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# tdg qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# t qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# t qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# tdg qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# t qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# tdg qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# t qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# tdg qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# t qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# t qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# tdg qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# tdg qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[6];
# t qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# tdg qr[1];
# t qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[4];
# tdg qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# tdg qr[0];
# tdg qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# t qr[2];
# t qr[1];
# t qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# tdg qr[1];
# t qr[2];
# cx qr[0],qr[1];
# tdg qr[1];
# tdg qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# t qr[3];
# t qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# t qr[3];
# t qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# tdg qr[5];
# t qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# tdg qr[5];
# t qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[2];
# barrier qr[3];
# barrier qr[4];
# barrier qr[5];
# barrier qr[6];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];
# measure qr[4] -> cr[4];
# measure qr[5] -> cr[5];
# measure qr[6] -> cr[6];

# %%
#other way complire and run:
job = execute(qc, backend='local_qasm_simulator', shots=1024, max_credits=3)

lapse = 0
interval = 5
while not job.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job.status)
    time.sleep(interval)
    lapse += 1
print(job.status)

print(job.result().get_counts(qc))
plot_histogram(job.result().get_counts(qc))
# Out:
# Status @ 0 seconds
# {'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': None}
# {'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': None}
# {'1111100': 1024}

# %%
#the circuit running is not the one we write
qobj = compile(qc, backend='local_qasm_simulator')

qasm_str = qp.get_compiled_qasm(qobj, 'Circuit')

qasm_circ = qiskit.load_qasm_string(qasm_str);
circuit_drawer(qasm_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
print(qasm_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# x qr[3];
# x qr[4];
# x qr[5];
# x qr[6];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[1];
# h qr[1];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[6];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[1],qr[5];
# h qr[1];
# barrier qr[0];
# h qr[0];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[4];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[4];
# cx qr[4],qr[3];
# u1(-0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[3];
# cx qr[0],qr[3];
# h qr[0];
# h qr[2];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[1],qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[2];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[2],qr[1];
# cx qr[0],qr[2];
# cx qr[1],qr[0];
# h qr[2];
# h qr[0];
# cx qr[0],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[0];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[4];
# cx qr[4],qr[3];
# cx qr[0],qr[4];
# h qr[0];
# h qr[1];
# cx qr[1],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[6],qr[5];
# cx qr[1],qr[6];
# h qr[1];
# barrier qr[2];
# barrier qr[3];
# barrier qr[4];
# barrier qr[5];
# barrier qr[6];
# measure qr[2] -> cr[2];
# measure qr[3] -> cr[3];
# measure qr[4] -> cr[4];
# measure qr[5] -> cr[5];
# measure qr[6] -> cr[6];

# %% [markdown]
# # Running on real device

# %%
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['operational'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

backend = lowest_pending_jobs()
print("The best backend is " + backend)
# Out:
# The best backend is ibmqx5

# %%
#to this case we need ibmqx5 - 16 qubits
backend = 'ibmqx5'
api.backend_status(backend)
# Out:
# {'available': True, 'backend': 'ibmqx5', 'pending_jobs': 1}

# %%
api.backend_calibration(backend)
# Out:
# {'backend': 'ibmqx5',
#  'lastUpdateDate': '2018-08-18T11:48:02.000Z',
#  'multiQubitGates': [{'gateError': {'date': '2018-08-18T11:48:02Z',
#     'value': 0.03937305685784165},
#    'name': 'CX1_0',
#    'qubits': [1, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.03757767453839178},
#    'name': 'CX1_2',
#    'qubits': [1, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.03867435070753919},
#    'name': 'CX2_3',
#    'qubits': [2, 3],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04612166778836588},
#    'name': 'CX3_4',
#    'qubits': [3, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:48:02Z', 'value': 0.06594757924507205},
#    'name': 'CX3_14',
#    'qubits': [3, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z',
#     'value': 0.026901703504286417},
#    'name': 'CX5_4',
#    'qubits': [5, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.03978532683436975},
#    'name': 'CX6_5',
#    'qubits': [6, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04046143792497861},
#    'name': 'CX6_7',
#    'qubits': [6, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z',
#     'value': 0.050746125814823156},
#    'name': 'CX6_11',
#    'qubits': [6, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04941664849220473},
#    'name': 'CX7_10',
#    'qubits': [7, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04365462179820884},
#    'name': 'CX8_7',
#    'qubits': [8, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.03433887092367563},
#    'name': 'CX9_8',
#    'qubits': [9, 8],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z',
#     'value': 0.041339639638807324},
#    'name': 'CX9_10',
#    'qubits': [9, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04685349131945504},
#    'name': 'CX11_10',
#    'qubits': [11, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.0400329120836819},
#    'name': 'CX12_5',
#    'qubits': [12, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04043751418181668},
#    'name': 'CX12_11',
#    'qubits': [12, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04081964037982791},
#    'name': 'CX12_13',
#    'qubits': [12, 13],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.02738483362469743},
#    'name': 'CX13_4',
#    'qubits': [13, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z',
#     'value': 0.050331744821149466},
#    'name': 'CX13_14',
#    'qubits': [13, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:48:02Z', 'value': 0.04342181628543473},
#    'name': 'CX15_0',
#    'qubits': [15, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z',
#     'value': 0.036253670280643746},
#    'name': 'CX15_2',
#    'qubits': [15, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-18T11:15:23Z', 'value': 0.04543727558584673},
#    'name': 'CX15_14',
#    'qubits': [15, 14],
#    'type': 'CX'}],
#  'qubits': [{'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0024695242079452173},
#    'name': 'Q0',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.08099999999999996}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.003649645872498608},
#    'name': 'Q1',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.06059999999999999}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0029754977337139166},
#    'name': 'Q2',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.06010000000000004}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0033986967288602843},
#    'name': 'Q3',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.048699999999999966}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0012862338485014613},
#    'name': 'Q4',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.06889999999999996}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0016720073718612949},
#    'name': 'Q5',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.05679999999999996}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.003026048646266266},
#    'name': 'Q6',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.052999999999999936}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z', 'value': 0.00201393870499883},
#    'name': 'Q7',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.09099999999999997}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0023319679200368704},
#    'name': 'Q8',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.09109999999999996}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0011279253414890333},
#    'name': 'Q9',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.11840000000000006}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0021776277152734114},
#    'name': 'Q10',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.07180000000000009}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z', 'value': 0.00255056900557199},
#    'name': 'Q11',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.05170000000000008}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0017670099235115866},
#    'name': 'Q12',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.12150000000000005}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.002150561708916643},
#    'name': 'Q13',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.04359999999999997}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.0032871616851860574},
#    'name': 'Q14',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.056599999999999984}},
#   {'gateError': {'date': '2018-08-18T10:41:05Z',
#     'value': 0.003788967351837147},
#    'name': 'Q15',
#    'readoutError': {'date': '2018-08-18T10:33:38Z',
#     'value': 0.09819999999999995}}]}

# %%
api.backend_parameters(backend)
# Out:
# {'backend': 'ibmqx5',
#  'fridgeParameters': {'Temperature': {'date': '2018-08-18T03:42:08Z',
#    'unit': 'K',
#    'value': 0.0143556},
#   'cooldownDate': '2017-09-15'},
#  'lastUpdateDate': '2018-08-18T10:35:09.000Z',
#  'qubits': [{'T1': {'date': '2018-08-18T10:34:06Z',
#     'unit': 'µs',
#     'value': 41.6},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 22.8},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.2559419},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q0'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 40.2},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 60.9},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.3960117},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q1'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 43.8},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 67.6},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.275714},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q2'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 22.7},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 89.1},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.0830855},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q3'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 53.1},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 80.6},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 4.9791971},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q4'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 46},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 48.8},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.1515115},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q5'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 36.4},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 29.9},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.3058145},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q6'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 36},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 46.3},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.252376},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q7'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 20.2},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 35.1},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.115211},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q8'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 53},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 81.7},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.1554108},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q9'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 50.6},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 79},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.0425489},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q10'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 58.8},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 88.5},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.1108855},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q11'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 37.3},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 42.6},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 4.946834},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q12'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 39.2},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 35},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.0882595},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q13'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 42},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 76.8},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 4.8704885},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q14'},
#   {'T1': {'date': '2018-08-18T10:34:06Z', 'unit': 'µs', 'value': 31},
#    'T2': {'date': '2018-08-18T10:35:09Z', 'unit': 'µs', 'value': 43.4},
#    'buffer': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-18T10:05:16Z',
#     'units': 'GHz',
#     'value': 5.104745},
#    'gateTime': {'date': '2018-08-18T10:05:16Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q15'}]}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f5f8c013d90> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.local/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x179215 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x179215 pixels is too large. It must be less than 2^16 in each direction.

# %%
print(qs_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[16];
# creg cr[7];
# u2(0,3.14159265358979) q[15];
# u3(3.14159265358979,0,3.14159265358979) q[14];
# u3(3.14159265358979,0,3.14159265358979) q[13];
# u3(3.14159265358979,0,3.14159265358979) q[3];
# u3(3.14159265358979,0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[13],q[14];
# cx q[1],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.92699081698724) q[15];
# u1(-0.785398163397448) q[2];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(-0.785398163397448,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[15],q[14];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,2.35619449019234) q[1];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.92699081698724) q[0];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[0];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[1];
# u1(0.785398163397448) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(-0.785398163397448,3.14159265358979) q[0];
# cx q[1],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# u2(-0.785398163397448,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[13];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[1];
# u1(-0.785398163397448) q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(-0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[2];
# u2(0,3.92699081698724) q[0];
# u2(0,2.35619449019234) q[15];
# u1(-0.785398163397448) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(-0.785398163397448) q[1];
# u1(-0.785398163397448) q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u1(0.785398163397448) q[0];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# barrier q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[15],q[0];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,2.35619449019234) q[3];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0.785398163397448,3.14159265358979) q[15];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[14];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[15],q[0];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,2.35619449019234) q[1];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[2],q[3];
# cx q[1],q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(-0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[15];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[3],q[14];
# cx q[15],q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[1];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[2];
# cx q[13],q[14];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u1(0.785398163397448) q[1];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[2];
# cx q[1],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# u1(0.785398163397448) q[2];
# cx q[1],q[0];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[1];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[13];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[15],q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# cx q[15],q[14];
# u1(0.785398163397448) q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u1(-0.785398163397448) q[0];
# u2(0,3.92699081698724) q[2];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u1(-0.785398163397448) q[15];
# u1(0.785398163397448) q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[15],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,2.35619449019234) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u2(-0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[2];
# cx q[13],q[14];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# cx q[2],q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# u1(-0.785398163397448) q[14];
# u1(0.785398163397448) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(-0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0,3.92699081698724) q[0];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# u2(0,2.35619449019234) q[1];
# cx q[1],q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# barrier q[0];
# measure q[0] -> cr[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[2];
# u1(0.785398163397448) q[15];
# u2(0,3.92699081698724) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[13];
# cx q[3],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# barrier q[14];
# u2(0,3.14159265358979) q[3];
# measure q[14] -> cr[6];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# measure q[13] -> cr[5];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u2(0,3.92699081698724) q[1];
# u2(0,3.92699081698724) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# barrier q[2];
# measure q[2] -> cr[4];
# u2(0,3.14159265358979) q[1];
# barrier q[1];
# measure q[1] -> cr[3];

# %%
shots=1024
max_credits=3
job_exp = execute(qc, backend=backend, shots=shots, max_credits=max_credits)

lapse = 0
interval = 10
while not job_exp.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job_exp.status)
    time.sleep(interval)
    lapse += 1
print(job_exp.status)
# Out:
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 10 seconds
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 20 seconds
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 30 seconds
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 40 seconds
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 50 seconds
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# {'job_id': '5b7830adbc84ce00395cb72c', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}

# %%
plot_histogram(job_exp.result().get_counts(qc))

# %%
job_exp.result().get_data('Circuit')
# Out:
# {'counts': {'0000000': 77,
#   '0000100': 58,
#   '0001000': 54,
#   '0001100': 50,
#   '0010000': 50,
#   '0010100': 25,
#   '0011000': 29,
#   '0011100': 14,
#   '0100000': 83,
#   '0100100': 49,
#   '0101000': 39,
#   '0101100': 34,
#   '0110000': 23,
#   '0110100': 27,
#   '0111000': 17,
#   '0111100': 8,
#   '1000000': 51,
#   '1000100': 33,
#   '1001000': 35,
#   '1001100': 23,
#   '1010000': 22,
#   '1010100': 16,
#   '1011000': 18,
#   '1011100': 15,
#   '1100000': 39,
#   '1100100': 35,
#   '1101000': 19,
#   '1101100': 21,
#   '1110000': 26,
#   '1110100': 11,
#   '1111000': 16,
#   '1111100': 7},
#  'date': '2018-08-18T14:44:56.068Z',
#  'time': 24.29253101348877}
