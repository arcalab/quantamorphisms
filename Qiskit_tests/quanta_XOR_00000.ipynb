# %% [markdown]
# # matrix fold of gate XOR

# %%
# Checking the version of PYTHON; we only support > 3.5
import sys
sys.path.append('../../../Transferências/qiskit-sdk-py-master')

if sys.version_info < (3,5):
    raise Exception('Please use Python version 3.5 or greater.')

import qiskit
import numpy

# Import the QISKit
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, QuantumProgram, Result
from qiskit import available_backends, execute, register, get_backend
import getpass, time
import Qconfig
from qiskit import compile


# import basic plot tools
from qiskit.tools.visualization import plot_histogram, circuit_drawer, plot_state

#information of API
from IBMQuantumExperience import IBMQuantumExperience

# Import tomography tools
import qiskit.tools.qcvv.tomography as tomo

# Aditional packages
from qiskit.tools.qi.qi import *

# %%
api = IBMQuantumExperience(Qconfig.APItoken)
myCredits = api.get_my_credits()

print(myCredits)

# set the APIToken and API url
try:
    register(Qconfig.APItoken,Qconfig.config['url'])

    print('\nYou have access to great power!')
    print(available_backends({'local': False, 'simulator': False}))
    print('Available simulators:')
    print(available_backends({'simulator':True}))
except: 
    print('Something went wrong.\nDid you enter a correct token?')
# Out:
# {'maxUserType': 15, 'promotional': 0, 'remaining': 12}
#
# You have access to great power!
# ['ibmq_16_rueschlikon', 'ibmq_5_tenerife', 'ibmq_5_yorktown']
# Available simulators:
# ['ibmq_qasm_simulator', 'local_qasm_simulator', 'local_statevector_simulator', 'local_unitary_simulator']

# %%
# Creating Programs
# create QuantumProgram object instance.
qp = QuantumProgram()

# Creating Registers
# create Quantum Register called "qr" with 7 qubits 
qr = qp.create_quantum_register('qr', 7)
# create Classical Register  called "cr" with 7 bits
cr = qp.create_classical_register('cr', 7)

# Creating Circuits
# create Quantum Circuit called "qc" involving your Quantum Register "qr"
# and your Classical Register "cr"
qc = qp.create_circuit('Circuit', [qr], [cr])

# %%
# Get the components.

# get the circuit by Name
circuit = qp.get_circuit('Circuit')

# get the Quantum Register by Name
quantum_r = qp.get_quantum_register('qr')

# get the Classical Register by Name
classical_r = qp.get_classical_register('cr')

# %%
#preparing qubits

# the circuit we want:
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[0])
qc.tdg(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.t(qr[2])
qc.tdg(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.t(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.tdg(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.t(qr[3])
qc.tdg(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.t(qr[1])
qc.tdg(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[0])
qc.tdg(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.t(qr[2])
qc.t(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.tdg(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.t(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.tdg(qr[3])
qc.tdg(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.t(qr[1])
qc.tdg(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.tdg(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.t(qr[2])
qc.t(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.tdg(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.t(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.tdg(qr[3])
qc.tdg(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.t(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.tdg(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[2])
qc.t(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.t(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.tdg(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.tdg(qr[3])
qc.t(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.t(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.t(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.tdg(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[2])
qc.tdg(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.tdg(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.t(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.t(qr[3])
qc.t(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.t(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.tdg(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.t(qr[2])
qc.t(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.tdg(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.t(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.tdg(qr[3])
qc.tdg(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.t(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[2])
qc.t(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.t(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.tdg(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.tdg(qr[3])
qc.t(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.t(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
qc.barrier(qr[5])
qc.h(qr[5])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[0])
qc.t(qr[1])
qc.cx(qr[5],qr[0])
qc.cx(qr[0],qr[1])
qc.tdg(qr[5])
qc.t(qr[1])
qc.cx(qr[5],qr[1])
qc.h(qr[5])
qc.barrier(qr[6])
qc.h(qr[6])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[2])
qc.tdg(qr[3])
qc.cx(qr[6],qr[2])
qc.cx(qr[2],qr[3])
qc.tdg(qr[6])
qc.tdg(qr[3])
qc.cx(qr[6],qr[3])
qc.h(qr[6])
qc.h(qr[4])
qc.t(qr[4])
qc.t(qr[5])
qc.t(qr[6])
qc.cx(qr[5],qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.tdg(qr[5])
qc.t(qr[4])
qc.cx(qr[6],qr[5])
qc.tdg(qr[5])
qc.tdg(qr[6])
qc.cx(qr[4],qr[5])
qc.cx(qr[6],qr[4])
qc.cx(qr[5],qr[6])
qc.h(qr[4])
qc.h(qr[6])
qc.cx(qr[6],qr[3])
qc.t(qr[3])
qc.t(qr[6])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.t(qr[3])
qc.t(qr[2])
qc.cx(qr[2],qr[3])
qc.cx(qr[6],qr[2])
qc.h(qr[6])
qc.h(qr[5])
qc.cx(qr[5],qr[1])
qc.tdg(qr[1])
qc.t(qr[5])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.tdg(qr[1])
qc.t(qr[0])
qc.cx(qr[0],qr[1])
qc.cx(qr[5],qr[0])
qc.h(qr[5])
# don't forget update the number of qubits and bits registered

# %%
circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
job = execute(qc, backend='local_unitary_simulator')
np.round(job.result().get_data(qc)['unitary'], 3)
# Out:
# array([[1.-0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#        ...,
#        [0.+0.j, 0.+0.j, 0.+0.j, ..., 1.-0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 1.-0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 1.-0.j]])

# %%
qc.barrier(qr[4])
qc.barrier(qr[3])
qc.barrier(qr[2])
qc.barrier(qr[1])
qc.barrier(qr[0])

qc.measure(qr[4],cr[4])
qc.measure(qr[3],cr[3])
qc.measure(qr[2],cr[2])
qc.measure(qr[1],cr[1])
qc.measure(qr[0],cr[0])

circuit_drawer(qc)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
qp.get_circuit_names()
# Out:
# ['Circuit']

# %%
# QASM from a program

QASM_source = qp.get_qasm('Circuit')

print(QASM_source)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# t qr[0];
# tdg qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# t qr[1];
# cx qr[5],qr[1];
# h qr[5];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# t qr[2];
# tdg qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# t qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# tdg qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# t qr[3];
# tdg qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# tdg qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# t qr[1];
# tdg qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# t qr[0];
# tdg qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# t qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# t qr[2];
# t qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# tdg qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# t qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# tdg qr[3];
# tdg qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# tdg qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# t qr[1];
# tdg qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# t qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# tdg qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# t qr[2];
# t qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# tdg qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# t qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# tdg qr[3];
# tdg qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# t qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# tdg qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# t qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# tdg qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[2];
# t qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# t qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# tdg qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# tdg qr[3];
# t qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# t qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# tdg qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# t qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# tdg qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[2];
# tdg qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# tdg qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# t qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# t qr[3];
# t qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# t qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# tdg qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# t qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# t qr[2];
# t qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# tdg qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# t qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# tdg qr[3];
# tdg qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# tdg qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# t qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# t qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[2];
# t qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# t qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# tdg qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# tdg qr[3];
# t qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# tdg qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# t qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[0];
# t qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# tdg qr[5];
# t qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[2];
# tdg qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# tdg qr[6];
# tdg qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# t qr[4];
# t qr[5];
# t qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# tdg qr[5];
# t qr[4];
# cx qr[6],qr[5];
# tdg qr[5];
# tdg qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# t qr[3];
# t qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# t qr[3];
# t qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# tdg qr[1];
# t qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# tdg qr[1];
# t qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[4];
# barrier qr[3];
# barrier qr[2];
# barrier qr[1];
# barrier qr[0];
# measure qr[4] -> cr[4];
# measure qr[3] -> cr[3];
# measure qr[2] -> cr[2];
# measure qr[1] -> cr[1];
# measure qr[0] -> cr[0];

# %%
#other way complire and run:
job = execute(qc, backend='local_qasm_simulator', shots=1024, max_credits=3)

lapse = 0
interval = 5
while not job.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job.status)
    time.sleep(interval)
    lapse += 1
print(job.status)

print(job.result().get_counts(qc))
plot_histogram(job.result().get_counts(qc))
# Out:
# Status @ 0 seconds
# {'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': None}
# {'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': None}
# {'0000000': 1024}

# %%
#the circuit running is not the one we write
qobj = compile(qc, backend='local_qasm_simulator')

qasm_str = qp.get_compiled_qasm(qobj, 'Circuit')

qasm_circ = qiskit.load_qasm_string(qasm_str);
circuit_drawer(qasm_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...

# %%
print(qasm_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg qr[7];
# creg cr[7];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(0.785398163397448) qr[2];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[0];
# u1(-0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[2];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(-0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(-0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[2];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(-0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[5];
# h qr[5];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[0];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[0];
# cx qr[0],qr[1];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[1];
# cx qr[5],qr[1];
# h qr[5];
# barrier qr[6];
# h qr[6];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[2];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[2];
# cx qr[2],qr[3];
# u1(-0.785398163397448) qr[6];
# u1(-0.785398163397448) qr[3];
# cx qr[6],qr[3];
# h qr[6];
# h qr[4];
# u1(0.785398163397448) qr[4];
# u1(0.785398163397448) qr[5];
# u1(0.785398163397448) qr[6];
# cx qr[5],qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# u1(-0.785398163397448) qr[5];
# u1(0.785398163397448) qr[4];
# cx qr[6],qr[5];
# u1(-0.785398163397448) qr[5];
# u1(-0.785398163397448) qr[6];
# cx qr[4],qr[5];
# cx qr[6],qr[4];
# cx qr[5],qr[6];
# h qr[4];
# h qr[6];
# cx qr[6],qr[3];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[6];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# u1(0.785398163397448) qr[3];
# u1(0.785398163397448) qr[2];
# cx qr[2],qr[3];
# cx qr[6],qr[2];
# h qr[6];
# h qr[5];
# cx qr[5],qr[1];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[5];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# u1(-0.785398163397448) qr[1];
# u1(0.785398163397448) qr[0];
# cx qr[0],qr[1];
# cx qr[5],qr[0];
# h qr[5];
# barrier qr[4];
# barrier qr[3];
# barrier qr[2];
# barrier qr[1];
# barrier qr[0];
# measure qr[4] -> cr[4];
# measure qr[3] -> cr[3];
# measure qr[2] -> cr[2];
# measure qr[1] -> cr[1];
# measure qr[0] -> cr[0];

# %% [markdown]
# # Running on real device

# %%
def lowest_pending_jobs():
    """Returns the backend with lowest pending jobs."""
    list_of_backends = available_backends(
        {'local': False, 'simulator': False})
    device_status = [get_backend(backend).status
                     for backend in list_of_backends]

    best = min([x for x in device_status if x['operational'] is True],
               key=lambda x: x['pending_jobs'])
    return best['name']

backend = lowest_pending_jobs()
print("The best backend is " + backend)
# Out:
# The best backend is ibmqx5

# %%
#to this case we need ibmqx5 - 16 qubits
backend = 'ibmqx5'
api.backend_status(backend)
# Out:
# {'available': True, 'backend': 'ibmqx5', 'pending_jobs': 15}

# %%
api.backend_calibration(backend)
# Out:
# {'backend': 'ibmqx5',
#  'lastUpdateDate': '2018-08-15T11:44:46.000Z',
#  'multiQubitGates': [{'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.03976789467572084},
#    'name': 'CX1_0',
#    'qubits': [1, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.04259136061573582},
#    'name': 'CX1_2',
#    'qubits': [1, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.04689156023448646},
#    'name': 'CX2_3',
#    'qubits': [2, 3],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.03763504291162942},
#    'name': 'CX3_4',
#    'qubits': [3, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.06497451042655555},
#    'name': 'CX3_14',
#    'qubits': [3, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.0318316471912545},
#    'name': 'CX5_4',
#    'qubits': [5, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.039239297031745085},
#    'name': 'CX6_5',
#    'qubits': [6, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.06535320988032259},
#    'name': 'CX6_7',
#    'qubits': [6, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.034802688933202264},
#    'name': 'CX6_11',
#    'qubits': [6, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.08818852491362159},
#    'name': 'CX7_10',
#    'qubits': [7, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.08053987133980856},
#    'name': 'CX8_7',
#    'qubits': [8, 7],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.023729865719553572},
#    'name': 'CX9_8',
#    'qubits': [9, 8],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.030069368649473127},
#    'name': 'CX9_10',
#    'qubits': [9, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.029741960747161372},
#    'name': 'CX11_10',
#    'qubits': [11, 10],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.03878443011794416},
#    'name': 'CX12_5',
#    'qubits': [12, 5],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.031055346000024575},
#    'name': 'CX12_11',
#    'qubits': [12, 11],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.02571438238671117},
#    'name': 'CX12_13',
#    'qubits': [12, 13],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.02465853486310371},
#    'name': 'CX13_4',
#    'qubits': [13, 4],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.06113314944324491},
#    'name': 'CX13_14',
#    'qubits': [13, 14],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z', 'value': 0.04702852615984435},
#    'name': 'CX15_0',
#    'qubits': [15, 0],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:11:58Z',
#     'value': 0.044588056956553046},
#    'name': 'CX15_2',
#    'qubits': [15, 2],
#    'type': 'CX'},
#   {'gateError': {'date': '2018-08-15T11:44:46Z', 'value': 0.06539183458235143},
#    'name': 'CX15_14',
#    'qubits': [15, 14],
#    'type': 'CX'}],
#  'qubits': [{'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.002117800628844646},
#    'name': 'Q0',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.053100000000000036}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0035766080666581046},
#    'name': 'Q1',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.05359999999999998}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0036295125450760413},
#    'name': 'Q2',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.08529999999999993}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.001584728512430189},
#    'name': 'Q3',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.05740000000000001}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.001518096776740474},
#    'name': 'Q4',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.07790000000000008}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0021546932414572284},
#    'name': 'Q5',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.06410000000000005}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0021957910375787204},
#    'name': 'Q6',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.045700000000000074}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.006939742717008757},
#    'name': 'Q7',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.07020000000000004}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0013137416714372185},
#    'name': 'Q8',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.048699999999999966}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0009781170220734547},
#    'name': 'Q9',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.13190000000000002}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0018282341054356444},
#    'name': 'Q10',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.06830000000000003}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.0014422828916563213},
#    'name': 'Q11',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.04510000000000003}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.001197931862451651},
#    'name': 'Q12',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.11159999999999992}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.001610861822263443},
#    'name': 'Q13',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.04180000000000006}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.003324697838995083},
#    'name': 'Q14',
#    'readoutError': {'date': '2018-08-15T10:27:30Z',
#     'value': 0.057499999999999996}},
#   {'gateError': {'date': '2018-08-15T10:35:01Z',
#     'value': 0.003846981379679093},
#    'name': 'Q15',
#    'readoutError': {'date': '2018-08-15T10:27:30Z', 'value': 0.1059}}]}

# %%
api.backend_parameters(backend)
# Out:
# {'backend': 'ibmqx5',
#  'fridgeParameters': {'Temperature': {'date': '2018-08-15T03:52:29Z',
#    'unit': 'K',
#    'value': 0.0144237},
#   'cooldownDate': '2017-09-15'},
#  'lastUpdateDate': '2018-08-15T10:29:02.000Z',
#  'qubits': [{'T1': {'date': '2018-08-15T10:27:59Z',
#     'unit': 'µs',
#     'value': 44.3},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 20.8},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.2559176},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q0'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 38.6},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 61.1},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.3960051},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q1'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 39.8},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 53.3},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.2757122},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q2'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 36.2},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 51.7},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.0830885},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q3'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 51.1},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 73},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 4.979197},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q4'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 52.1},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 44.7},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.1515154},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q5'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 37.4},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 62.5},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.3058104},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q6'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 32.3},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 36.6},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.2523727},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q7'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 52.4},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 108.1},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.1152059},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q8'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 50},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 91.1},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.1554094},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q9'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 56},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 77.9},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.0425347},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q10'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 51.6},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 78.7},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.1108798},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q11'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 49.2},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 43.8},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 4.9468336},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q12'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 46.4},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 86.8},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.0882573},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q13'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 25.8},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 32.1},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 4.8704819},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q14'},
#   {'T1': {'date': '2018-08-15T10:27:59Z', 'unit': 'µs', 'value': 42},
#    'T2': {'date': '2018-08-15T10:29:02Z', 'unit': 'µs', 'value': 73.4},
#    'buffer': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 10},
#    'frequency': {'date': '2018-08-15T10:05:08Z',
#     'units': 'GHz',
#     'value': 5.104732},
#    'gateTime': {'date': '2018-08-15T10:05:08Z', 'unit': 'ns', 'value': 80},
#    'name': 'Q15'}]}

# %%
qobj = compile(qc, backend=backend)

qs_str = qp.get_compiled_qasm(qobj, 'Circuit')

qs_circ = qiskit.load_qasm_string(qs_str);
circuit_drawer(qs_circ)
# Out:
# WARNING: Unable to compile latex. Circuit too large for memory. Skipping latex circuit drawing...
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fd992c73e18> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     148             def post_execute():
#     149                 if matplotlib.is_interactive():
# --> 150                     draw_all()
#     151
#     152             # IPython >= 2
#
# ~/.local/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     148         for f_mgr in cls.get_all_fig_managers():
#     149             if force or f_mgr.canvas.figure.stale:
# --> 150                 f_mgr.canvas.draw_idle()
#     151
#     152 atexit.register(Gcf.destroy_all)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2059         if not self._is_idle_drawing:
#    2060             with self._idle_draw_cntx():
# -> 2061                 self.draw(*args, **kwargs)
#    2062
#    2063     def draw_cursor(self, event):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x157543 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2214                     orientation=orientation,
#    2215                     dryrun=True,
# -> 2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
#    2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     420         Draw the figure using the renderer
#     421         """
# --> 422         self.renderer = self.get_renderer(cleared=True)
#     423         # acquire a lock on the shared font cache
#     424         RendererAgg.lock.acquire()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     442
#     443         if need_new_renderer:
# --> 444             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     445             self._lastKey = key
#     446         elif cleared:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      90         self.width = width
#      91         self.height = height
# ---> 92         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      93         self._filter_renderers = []
#      94
#
# ValueError: Image size of 1384x157543 pixels is too large. It must be less than 2^16 in each direction.

# %%
print(qs_str)
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[16];
# creg cr[7];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[3];
# cx q[15],q[14];
# cx q[2],q[3];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[15];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.92699081698724) q[1];
# u1(-0.785398163397448) q[0];
# cx q[1],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[1],q[0];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u1(-0.785398163397448) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,2.35619449019234) q[3];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,2.35619449019234) q[14];
# u1(0.785398163397448) q[3];
# cx q[15],q[0];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[13];
# cx q[3],q[14];
# u2(0,2.35619449019234) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# barrier q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[3],q[14];
# u1(-0.785398163397448) q[3];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# cx q[13],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(-0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# barrier q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(-0.785398163397448) q[2];
# u2(0,3.92699081698724) q[1];
# cx q[1],q[0];
# u2(-0.785398163397448,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[15],q[2];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# cx q[15],q[14];
# u1(0.785398163397448) q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[2];
# u1(0.785398163397448) q[15];
# u2(0,2.35619449019234) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u2(0,3.92699081698724) q[1];
# u2(0,2.35619449019234) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[15],q[2];
# u1(-0.785398163397448) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u1(0.785398163397448) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# cx q[15],q[0];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[0];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u1(0.785398163397448) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[2];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[0];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u1(-0.785398163397448) q[0];
# u1(-0.785398163397448) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[1];
# barrier q[15];
# barrier q[1];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[1];
# cx q[15],q[14];
# cx q[1],q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[0];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[14];
# cx q[1],q[2];
# u1(-0.785398163397448) q[1];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# cx q[15],q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[3];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[3],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[0];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[0];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0.785398163397448,3.14159265358979) q[3];
# u2(-0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(-0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# barrier q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.92699081698724) q[1];
# u1(0.785398163397448) q[0];
# cx q[1],q[2];
# u2(-0.785398163397448,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# cx q[15],q[0];
# u2(0.785398163397448,3.14159265358979) q[15];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(-0.785398163397448,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[15],q[2];
# cx q[2],q[3];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,2.35619449019234) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u1(0.785398163397448) q[3];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[3],q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u1(0.785398163397448) q[15];
# u1(0.785398163397448) q[14];
# u1(0.785398163397448) q[13];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(-0.785398163397448) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# barrier q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,2.35619449019234) q[15];
# u1(0.785398163397448) q[0];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u1(0.785398163397448) q[0];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0.785398163397448,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.92699081698724) q[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[2],q[3];
# cx q[1],q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[3];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[15],q[2];
# cx q[2],q[3];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[13];
# cx q[3],q[14];
# u2(0,2.35619449019234) q[14];
# u2(0,2.35619449019234) q[3];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u1(0.785398163397448) q[15];
# u2(0,2.35619449019234) q[14];
# u1(0.785398163397448) q[13];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[15];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.92699081698724) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,2.35619449019234) q[1];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[1],q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[2],q[3];
# cx q[1],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[3];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u1(-0.785398163397448) q[14];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[2];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0.785398163397448,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[2],q[3];
# u1(-0.785398163397448) q[3];
# u2(0,2.35619449019234) q[2];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# cx q[15],q[14];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.92699081698724) q[0];
# u2(0,3.14159265358979) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.92699081698724) q[14];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[13];
# barrier q[13];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(-0.785398163397448,3.14159265358979) q[14];
# cx q[13],q[14];
# u1(-0.785398163397448) q[13];
# u2(0,3.14159265358979) q[14];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0.785398163397448,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# u3(-0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[2],q[3];
# cx q[1],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# cx q[2],q[3];
# u2(-0.785398163397448,3.14159265358979) q[3];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[1];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# cx q[3],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[3];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# cx q[15],q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[2];
# u3(0.785398163397448,1.57079632679490,4.71238898038469) q[15];
# u2(0.785398163397448,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# u2(0,3.14159265358979) q[0];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[2];
# barrier q[15];
# u2(0,3.14159265358979) q[2];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[2];
# u2(0,3.14159265358979) q[1];
# cx q[1],q[0];
# cx q[1],q[2];
# u2(0,3.92699081698724) q[2];
# u1(0.785398163397448) q[1];
# cx q[15],q[0];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u2(0,3.14159265358979) q[3];
# u2(0,3.14159265358979) q[2];
# cx q[2],q[3];
# u1(0.785398163397448) q[3];
# cx q[1],q[2];
# u1(0.785398163397448) q[2];
# cx q[2],q[3];
# barrier q[3];
# cx q[1],q[2];
# measure q[3] -> cr[3];
# barrier q[2];
# u2(0,3.14159265358979) q[1];
# measure q[2] -> cr[2];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# u2(0,3.14159265358979) q[0];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[0];
# cx q[15],q[14];
# measure q[0] -> cr[4];
# u1(0.785398163397448) q[15];
# u1(-0.785398163397448) q[14];
# cx q[13],q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[13];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[15];
# cx q[15],q[14];
# u2(0,2.35619449019234) q[15];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0.785398163397448,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# u2(0,3.14159265358979) q[13];
# cx q[13],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[15],q[14];
# u2(0,3.14159265358979) q[14];
# cx q[13],q[14];
# barrier q[14];
# u2(0,3.14159265358979) q[13];
# measure q[14] -> cr[0];
# u2(0,3.14159265358979) q[15];
# barrier q[15];
# measure q[15] -> cr[1];

# %%
shots=1024
max_credits=3
job_exp = execute(qc, backend=backend, shots=shots, max_credits=max_credits)

lapse = 0
interval = 10
while not job_exp.done:
    print('Status @ {} seconds'.format(interval * lapse))
    print(job_exp.status)
    time.sleep(interval)
    lapse += 1
print(job_exp.status)
# Out:
# Status @ 0 seconds
# {'job_id': None, 'status': <JobStatus.INITIALIZING: 'job is being initialized'>, 'status_msg': 'Job is initializing. Please, wait a moment.'}
# Status @ 10 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 16}
# Status @ 20 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 15}
# Status @ 30 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 14}
# Status @ 40 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 14}
# Status @ 50 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 13}
# Status @ 60 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 13}
# Status @ 70 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 12}
# Status @ 80 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 11}
# Status @ 90 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 11}
# Status @ 100 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 10}
# Status @ 110 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 120 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 9}
# Status @ 130 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 8}
# Status @ 140 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 7}
# Status @ 150 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 7}
# Status @ 160 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 170 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 5}
# Status @ 180 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 7}
# Status @ 190 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 6}
# Status @ 200 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 5}
# Status @ 210 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 5}
# Status @ 220 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 4}
# Status @ 230 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 4}
# Status @ 240 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 250 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 260 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 270 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 280 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 290 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 3}
# Status @ 300 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 310 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 2}
# Status @ 320 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.QUEUED: 'job is queued'>, 'status_msg': 'job is queued', 'queue_position': 1}
# Status @ 330 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 340 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.RUNNING: 'job is actively running'>, 'status_msg': 'job is actively running'}
# Status @ 350 seconds
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}
# {'job_id': '5b74bb7c3f516200393c8209', 'status': <JobStatus.DONE: 'job has successfully run'>, 'status_msg': 'job has successfully run'}

# %%
plot_histogram(job_exp.result().get_counts(qc))

# %%
job_exp.result().get_data('Circuit')
# Out:
# {'counts': {'0000000': 57,
#   '0000001': 48,
#   '0000010': 38,
#   '0000011': 31,
#   '0000100': 52,
#   '0000101': 31,
#   '0000110': 37,
#   '0000111': 22,
#   '0001000': 42,
#   '0001001': 23,
#   '0001010': 33,
#   '0001011': 20,
#   '0001100': 50,
#   '0001101': 23,
#   '0001110': 24,
#   '0001111': 17,
#   '0010000': 51,
#   '0010001': 35,
#   '0010010': 33,
#   '0010011': 25,
#   '0010100': 41,
#   '0010101': 40,
#   '0010110': 33,
#   '0010111': 22,
#   '0011000': 31,
#   '0011001': 23,
#   '0011010': 30,
#   '0011011': 21,
#   '0011100': 28,
#   '0011101': 20,
#   '0011110': 24,
#   '0011111': 19},
#  'date': '2018-08-15T23:54:22.262Z',
#  'time': 24.666361093521118}
